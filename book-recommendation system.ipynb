# %% [markdown]
# ## BOOK RECOMMENDATION SYSTEM
# In today's digital age, the vast expanse of available books can be overwhelming for readers seeking their next great read. To address this challenge, we present a book recommendation system designed to assist users in discovering books tailored to their preferences. Utilizing two comprehensive datasets—books, and ratings—our system employs two distinct recommendation models: a popularity-based model and a collaborative-based model.
#
# The popularity-based model leverages overall book ratings to suggest widely acclaimed books, ensuring users are introduced to popular and trending titles. Conversely, the collaborative-based model harnesses the power of user interaction data, providing personalized recommendations by identifying patterns and similarities among users' reading habits. By combining these models, our system offers a balanced approach, catering to both general trends and individual tastes, ultimately enhancing the user experience in book discovery.

# %% [markdown]
# #### DATA GATHERING AND DATA CLEANING

# %% [markdown]
# Importing various libraries.
#
# 1. The NumPy and pandas libraries are essential for data manipulation and analysis in Python.
# 2. NumPy is used for numerical computing in Python. It provides support for arrays, matrices, and many mathematical functions.
# 3. Pandas is a powerful data manipulation library built on top of NumPy. It provides data structures like DataFrame and Series for efficient ata manipulation.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# DATA GATHERING : For this project, two primary datasets were utilized: 'books' and 'ratings'. The 'books' dataset contains detailed information about each book, including identifiers, titles, authors, publication years, publishers, and cover images. The 'ratings' dataset captures user interactions by recording unique user IDs, book ISBNs, and the corresponding ratings. These datasets form the foundation for the recommendation models.

# %%
ratings = pd.read_csv('Ratings.csv')
books = pd.read_csv('Books.csv')
# Out:
# C:\Users\Shivani\AppData\Local\Temp\ipykernel_6984\1002755648.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %% [markdown]
# We will first use the info method of pandas which provides a concise summary of a DataFrame, including the index dtype, column dtypes, non-null values, and memory usage.

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %% [markdown]
# DATA CLEANING: Dropping columns 'Image-URL-S' and 'IMAGE-URL-L' and keeping only column 'IMAGE-URL-M'for giving reference to cover image.

# %%
books.drop(columns = ['Image-URL-S', 'Image-URL-L'], inplace = True)

# %% [markdown]
# Dealing with null values present in 'Book-Author' and 'Publisher' columns and then dropping them.

# %%
books[books['Book-Author'].isnull() | books['Publisher'].isnull()]
# Out:
#               ISBN                                         Book-Title  \
# 118033  0751352497                           A+ Quiz Masters:01 Earth
# 128890  193169656X                                        Tyrant Moon
# 129037  1931696993                                    Finders Keepers
# 187689  9627982032  The Credit Suisse Guide to Managing Your Perso...
#
#             Book-Author Year-Of-Publication                       Publisher  \
# 118033              NaN                1999              Dorling Kindersley
# 128890  Elaine Corvidae                2002                             NaN
# 129037  Linnea Sinclair                2001                             NaN
# 187689              NaN                1995  Edinburgh Financial Publishing
#
#                                               Image-URL-M
# 118033  http://images.amazon.com/images/P/0751352497.0...
# 128890  http://images.amazon.com/images/P/193169656X.0...
# 129037  http://images.amazon.com/images/P/1931696993.0...
# 187689  http://images.amazon.com/images/P/9627982032.0...

# %%
ratings[(ratings['ISBN'] =='0751352497') | (ratings['ISBN'] =='193169656X') | (ratings['ISBN'] =='1931696993') | (ratings['ISBN'] =='9627982032')]
# Out:
#         User-ID        ISBN  Book-Rating
# 273117    63714  0751352497           10
# 411773    98391  193169656X            9
# 411782    98391  1931696993            9
# 412805    98647  9627982032            8

# %%
ratings = ratings[~((ratings['ISBN'] =='0751352497') | (ratings['ISBN'] =='193169656X') | (ratings['ISBN'] =='1931696993') | (ratings['ISBN'] =='9627982032'))]

# %%
books.dropna(subset=['Book-Author'], inplace = True)

# %%
books.dropna(subset=['Publisher'], inplace = True)

# %% [markdown]
# #### POPULARITY BASED MODEL

# %% [markdown]
# To build the popularity-based model, we first merge the 'books' and 'ratings' datasets using the common 'ISBN' column. We then filter for books with at least 200 ratings, this is because by focusing on well-rated books, we can provide recommendations that are more likely to be universally appreciated and then we can finally sort them by their average rating to recommend the most popular titles.

# %% [markdown]
# Firstly, merging our two datasets on the basis of 'ISBN' column as it is present in both of the datasets.

# %%
books_ratings = books.merge(ratings, on='ISBN')

# %%
books_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031132 entries, 0 to 1031131
# Data columns (total 8 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   ISBN                 1031132 non-null  object
#  1   Book-Title           1031132 non-null  object
#  2   Book-Author          1031132 non-null  object
#  3   Year-Of-Publication  1031132 non-null  object
#  4   Publisher            1031132 non-null  object
#  5   Image-URL-M          1031132 non-null  object
#  6   User-ID              1031132 non-null  int64
#  7   Book-Rating          1031132 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 62.9+ MB

# %%
books_ratings
# Out:
#                ISBN                                         Book-Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1031127  0440400988                         There's a Bat in Bunk Five
# 1031128  0525447644                            From One to One Hundred
# 1031129  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031130  0192126040                        Republic (World's Classics)
# 1031131  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 0          Mark P. O. Morford                2002
# 1        Richard Bruce Wright                2001
# 2        Richard Bruce Wright                2001
# 3        Richard Bruce Wright                2001
# 4        Richard Bruce Wright                2001
# ...                       ...                 ...
# 1031127        Paula Danziger                1988
# 1031128            Teri Sloat                1991
# 1031129      Christine Wicker                2004
# 1031130                 Plato                1996
# 1031131   Christopher  Biffle                2000
#
#                                                 Publisher  \
# 0                                 Oxford University Press
# 1                                   HarperFlamingo Canada
# 2                                   HarperFlamingo Canada
# 3                                   HarperFlamingo Canada
# 4                                   HarperFlamingo Canada
# ...                                                   ...
# 1031127                   Random House Childrens Pub (Mm)
# 1031128                                      Dutton Books
# 1031129                                HarperSanFrancisco
# 1031130                           Oxford University Press
# 1031131  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                                Image-URL-M  User-ID  \
# 0        http://images.amazon.com/images/P/0195153448.0...        2
# 1        http://images.amazon.com/images/P/0002005018.0...        8
# 2        http://images.amazon.com/images/P/0002005018.0...    11400
# 3        http://images.amazon.com/images/P/0002005018.0...    11676
# 4        http://images.amazon.com/images/P/0002005018.0...    41385
# ...                                                    ...      ...
# 1031127  http://images.amazon.com/images/P/0440400988.0...   276463
# 1031128  http://images.amazon.com/images/P/0525447644.0...   276579
# 1031129  http://images.amazon.com/images/P/006008667X.0...   276680
# 1031130  http://images.amazon.com/images/P/0192126040.0...   276680
# 1031131  http://images.amazon.com/images/P/0767409752.0...   276680
#
#          Book-Rating
# 0                  0
# 1                  5
# 2                  0
# 3                  8
# 4                  0
# ...              ...
# 1031127            7
# 1031128            4
# 1031129            0
# 1031130            0
# 1031131            0
#
# [1031132 rows x 8 columns]

# %% [markdown]
# Grouping the 'books_ratings' dataset on the basis of 'Book-Title' and then finding out count and mean of ratings for each book.

# %%
num_of_ratings = books_ratings.groupby('Book-Title').count()['Book-Rating']
num_of_ratings = num_of_ratings.reset_index()
num_of_ratings.rename(columns = {'Book-Rating':'count_ratings'}, inplace = True)

# %%
mean_of_ratings = books_ratings.groupby('Book-Title').agg({'Book-Rating':'mean'})
mean_of_ratings = mean_of_ratings.reset_index()
mean_of_ratings.rename(columns = {'Book-Rating':'mean_ratings'}, inplace = True)

# %%
num_of_ratings
# Out:
#                                                Book-Title  count_ratings
# 0        A Light in the Storm: The Civil War Diary of ...              4
# 1                                   Always Have Popsicles              1
# 2                    Apple Magic (The Collector's series)              1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...              1
# 4        Beyond IBM: Leadership Marketing and Finance ...              1
# ...                                                   ...            ...
# 241063                                      Ã?Â?lpiraten.              2
# 241064                     Ã?Â?rger mit Produkt X. Roman.              4
# 241065                                Ã?Â?sterlich leben.              1
# 241066                              Ã?Â?stlich der Berge.              3
# 241067                                  Ã?Â?thique en toc              2
#
# [241068 rows x 2 columns]

# %%
mean_of_ratings
# Out:
#                                                Book-Title  mean_ratings
# 0        A Light in the Storm: The Civil War Diary of ...      2.250000
# 1                                   Always Have Popsicles      0.000000
# 2                    Apple Magic (The Collector's series)      0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...      8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...      0.000000
# ...                                                   ...           ...
# 241063                                      Ã?Â?lpiraten.      0.000000
# 241064                     Ã?Â?rger mit Produkt X. Roman.      5.250000
# 241065                                Ã?Â?sterlich leben.      7.000000
# 241066                              Ã?Â?stlich der Berge.      2.666667
# 241067                                  Ã?Â?thique en toc      4.000000
#
# [241068 rows x 2 columns]

# %% [markdown]
# Making a new dataframe df which includes count and mean of rating for each book.

# %%
df = num_of_ratings.merge(mean_of_ratings, on = 'Book-Title')

# %%
df
# Out:
#                                                Book-Title  count_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...              4
# 1                                   Always Have Popsicles              1
# 2                    Apple Magic (The Collector's series)              1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...              1
# 4        Beyond IBM: Leadership Marketing and Finance ...              1
# ...                                                   ...            ...
# 241063                                      Ã?Â?lpiraten.              2
# 241064                     Ã?Â?rger mit Produkt X. Roman.              4
# 241065                                Ã?Â?sterlich leben.              1
# 241066                              Ã?Â?stlich der Berge.              3
# 241067                                  Ã?Â?thique en toc              2
#
#         mean_ratings
# 0           2.250000
# 1           0.000000
# 2           0.000000
# 3           8.000000
# 4           0.000000
# ...              ...
# 241063      0.000000
# 241064      5.250000
# 241065      7.000000
# 241066      2.666667
# 241067      4.000000
#
# [241068 rows x 3 columns]

# %% [markdown]
# Now for creating popularity based model we want to consider only those books which have minimum of 200 ratings to ensure that the recommendations are based on a substantial amount of user feedback and then we will consider only those books as popular books whose average rating is more than 4.Lastly we can sort the books on the basis of average ratings.

# %%
popular_books = df[df['count_ratings'] > 200]

# %%
popular_books = popular_books[popular_books['mean_ratings'] > 4]

# %%
popular_books = popular_books.sort_values('mean_ratings', ascending = False)

# %%
popular_books = popular_books.reset_index()

# %%
popular_books.drop(columns = 'index', inplace = True)

# %% [markdown]
# Merging popular_books dataset with books dataset to get all the information of the most popular books.

# %%
popular_books = popular_books.merge(books, on = 'Book-Title')

# %% [markdown]
# Dropping duplicates on the basis of 'Book-Title' column if there are any.

# %%
popular_books.drop_duplicates(subset = 'Book-Title', inplace = True)

# %% [markdown]
# Now presenting final popular_books dataframe by dropping column 'ISBN' and resetting index.

# %%
popular_books.drop(columns= 'ISBN', inplace = True)

# %%
popular_books = popular_books.reset_index().drop(columns = 'index')

# %%
popular_books
# Out:
#                                            Book-Title  count_ratings  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)            428
# 1        Harry Potter and the Goblet of Fire (Book 4)            387
# 2      Harry Potter and the Sorcerer's Stone (Book 1)            278
# 3   Harry Potter and the Order of the Phoenix (Boo...            347
# 4       Ender's Game (Ender Wiggins Saga (Paperback))            249
# 5    Harry Potter and the Chamber of Secrets (Book 2)            556
# 6   The Hobbit : The Enchanting Prelude to The Lor...            281
# 7   The Fellowship of the Ring (The Lord of the Ri...            368
# 8   Harry Potter and the Sorcerer's Stone (Harry P...            575
# 9      The Two Towers (The Lord of the Rings, Part 2)            260
# 10                              To Kill a Mockingbird            510
# 11                                  The Da Vinci Code            898
# 12                 The Five People You Meet in Heaven            430
# 13                             The Catcher in the Rye            449
# 14  The Return of the King (The Lord of the Rings,...            211
# 15                          The Lovely Bones: A Novel           1295
# 16                                   The Great Gatsby            205
# 17                                               1984            284
# 18                           Prodigal Summer: A Novel            253
# 19                                         Neverwhere            265
# 20                            The Secret Life of Bees            774
# 21  Stupid White Men ...and Other Sorry Excuses fo...            283
# 22  Tuesdays with Morrie: An Old Man, a Young Man,...            493
# 23                The Red Tent (Bestselling Backlist)            723
# 24                                    Brave New World            226
# 25               The Hitchhiker's Guide to the Galaxy            268
# 26   Nickel and Dimed: On (Not) Getting By in America            335
# 27                                    The Tao of Pooh            211
# 28                                        Animal Farm            233
# 29                                      Into the Wild            252
# 30                                     Fahrenheit 451            409
# 31  A Walk in the Woods: Rediscovering America on ...            205
# 32                          Girl with a Pearl Earring            526
# 33                                              Night            202
# 34                                          Outlander            283
# 35      The Subtle Knife (His Dark Materials, Book 2)            225
# 36  The Color of Water: A Black Man's Tribute to H...            223
# 37  Where the Heart Is (Oprah's Book Club (Paperba...            585
# 38                     Seabiscuit: An American Legend            275
# 39                                         Life of Pi            664
# 40                                     The Bean Trees            389
# 41  A Child Called \It\": One Child's Courage to S...            265
# 42                                     ANGELA'S ASHES            279
# 43                                      High Fidelity            247
# 44                                        Good in Bed            490
# 45  Fast Food Nation: The Dark Side of the All-Ame...            321
# 46                                      American Gods            302
# 47                                 Skipping Christmas            322
# 48  Left Behind: A Novel of the Earth's Last Days ...            318
#
#     mean_ratings          Book-Author Year-Of-Publication  \
# 0       5.852804        J. K. Rowling                1999
# 1       5.824289        J. K. Rowling                2000
# 2       5.737410        J. K. Rowling                1998
# 3       5.501441        J. K. Rowling                2003
# 4       5.409639     Orson Scott Card                1992
# 5       5.183453        J. K. Rowling                2000
# 6       5.007117       J.R.R. TOLKIEN                1986
# 7       4.948370       J.R.R. TOLKIEN                1986
# 8       4.895652        J. K. Rowling                1999
# 9       4.880769       J.R.R. TOLKIEN                1986
# 10      4.700000           Harper Lee                1988
# 11      4.642539            Dan Brown                2003
# 12      4.551163          Mitch Albom                2003
# 13      4.545657        J.D. Salinger                1991
# 14      4.497630       J.R.R. TOLKIEN                1986
# 15      4.468726         Alice Sebold                2002
# 16      4.458537  F. Scott Fitzgerald                1999
# 17      4.454225        George Orwell                1990
# 18      4.450593   Barbara Kingsolver                2001
# 19      4.449057          Neil Gaiman                1998
# 20      4.447028        Sue Monk Kidd                2003
# 21      4.356890        Michael Moore                2002
# 22      4.354970          MITCH ALBOM                1997
# 23      4.334716        Anita Diamant                1998
# 24      4.331858        Aldous Huxley                1989
# 25      4.328358        Douglas Adams                1982
# 26      4.289552   Barbara Ehrenreich                2002
# 27      4.289100        Benjamin Hoff                1983
# 28      4.274678        George Orwell                2004
# 29      4.273810         Jon Krakauer                1997
# 30      4.264059         Ray Bradbury                1994
# 31      4.243902          Bill Bryson                1999
# 32      4.218631      Tracy Chevalier                2001
# 33      4.217822          Elie Wiesel                1982
# 34      4.173145       DIANA GABALDON                1996
# 35      4.124444       PHILIP PULLMAN                2002
# 36      4.107623        James McBride                1997
# 37      4.105983         Billie Letts                1998
# 38      4.098182    LAURA HILLENBRAND                2002
# 39      4.088855          Yann Martel                2002
# 40      4.087404   Barbara Kingsolver                1989
# 41      4.086792          Dave Pelzer                1995
# 42      4.075269        Frank McCourt                1996
# 43      4.056680          Nick Hornby                1996
# 44      4.055102      Jennifer Weiner                2002
# 45      4.037383       Eric Schlosser                2002
# 46      4.006623          Neil Gaiman                2002
# 47      4.006211         JOHN GRISHAM                2001
# 48      4.003145           Tim Lahaye                1996
#
#                         Publisher  \
# 0                      Scholastic
# 1                      Scholastic
# 2                      Scholastic
# 3                      Scholastic
# 4                       Tor Books
# 5                      Scholastic
# 6                         Del Rey
# 7                         Del Rey
# 8          Arthur A. Levine Books
# 9                         Del Rey
# 10     Little Brown &amp; Company
# 11                      Doubleday
# 12                       Hyperion
# 13                  Little, Brown
# 14                        Del Rey
# 15                  Little, Brown
# 16         Lb May &amp; Assoc Inc
# 17                    Signet Book
# 18                      Perennial
# 19                           Avon
# 20                  Penguin Books
# 21                    Regan Books
# 22                      Doubleday
# 23                    Picador USA
# 24                  Harpercollins
# 25                         Pocket
# 26                      Owl Books
# 27                  Penguin Books
# 28                         Signet
# 29                         Anchor
# 30                Distribooks Inc
# 31                 Broadway Books
# 32                    Plume Books
# 33                   Bantam Books
# 34                           Dell
# 35  Knopf Books for Young Readers
# 36                Riverhead Books
# 37                   Warner Books
# 38               Ballantine Books
# 39                       Harcourt
# 40                      Perennial
# 41          Health Communications
# 42                       Scribner
# 43                Riverhead Books
# 44        Washington Square Press
# 45                      Perennial
# 46                    HarperTorch
# 47                      Doubleday
# 48       Tyndale House Publishers
#
#                                           Image-URL-M
# 0   http://images.amazon.com/images/P/0439136350.0...
# 1   http://images.amazon.com/images/P/0439139597.0...
# 2   http://images.amazon.com/images/P/0590353403.0...
# 3   http://images.amazon.com/images/P/043935806X.0...
# 4   http://images.amazon.com/images/P/0312853238.0...
# 5   http://images.amazon.com/images/P/0439064872.0...
# 6   http://images.amazon.com/images/P/0345339681.0...
# 7   http://images.amazon.com/images/P/0345339703.0...
# 8   http://images.amazon.com/images/P/059035342X.0...
# 9   http://images.amazon.com/images/P/0345339711.0...
# 10  http://images.amazon.com/images/P/0446310786.0...
# 11  http://images.amazon.com/images/P/0385504209.0...
# 12  http://images.amazon.com/images/P/0786868716.0...
# 13  http://images.amazon.com/images/P/0316769487.0...
# 14  http://images.amazon.com/images/P/0345339738.0...
# 15  http://images.amazon.com/images/P/0316666343.0...
# 16  http://images.amazon.com/images/P/185326041X.0...
# 17  http://images.amazon.com/images/P/0451524934.0...
# 18  http://images.amazon.com/images/P/0060959037.0...
# 19  http://images.amazon.com/images/P/0380789019.0...
# 20  http://images.amazon.com/images/P/0142001740.0...
# 21  http://images.amazon.com/images/P/0060392452.0...
# 22  http://images.amazon.com/images/P/0385484518.0...
# 23  http://images.amazon.com/images/P/0312195516.0...
# 24  http://images.amazon.com/images/P/0060809833.0...
# 25  http://images.amazon.com/images/P/0671461494.0...
# 26  http://images.amazon.com/images/P/0805063897.0...
# 27  http://images.amazon.com/images/P/0140067477.0...
# 28  http://images.amazon.com/images/P/0451526341.0...
# 29  http://images.amazon.com/images/P/0385486804.0...
# 30  http://images.amazon.com/images/P/3257208626.0...
# 31  http://images.amazon.com/images/P/0767902521.0...
# 32  http://images.amazon.com/images/P/0452282152.0...
# 33  http://images.amazon.com/images/P/0553272535.0...
# 34  http://images.amazon.com/images/P/0440222915.0...
# 35  http://images.amazon.com/images/P/0375823468.0...
# 36  http://images.amazon.com/images/P/1573225789.0...
# 37  http://images.amazon.com/images/P/0446672211.0...
# 38  http://images.amazon.com/images/P/0449005615.0...
# 39  http://images.amazon.com/images/P/0151008116.0...
# 40  http://images.amazon.com/images/P/0060915544.0...
# 41  http://images.amazon.com/images/P/1558743669.0...
# 42  http://images.amazon.com/images/P/0684874350.0...
# 43  http://images.amazon.com/images/P/1573225517.0...
# 44  http://images.amazon.com/images/P/0743418174.0...
# 45  http://images.amazon.com/images/P/0060938455.0...
# 46  http://images.amazon.com/images/P/0380789035.0...
# 47  http://images.amazon.com/images/P/0385505833.0...
# 48  http://images.amazon.com/images/P/0842329129.0...

# %% [markdown]
# #### COLLABORATIVE BASED MODEL

# %% [markdown]
# The collaborative-based model focuses on recommending books by analyzing user ratings. It selects active users with at least 200 ratings and considers books with a minimum of 50 ratings to ensure reliable recommendations. By calculating similarity scores based on user ratings in a pivot table using cosine similarity, the model suggests books that share similar user preferences, aiming to enhance personalized recommendations effectively.

# %% [markdown]
# Using the dataset 'books_ratings' that we made earlier by merging datasets 'books' and 'ratings' on the basis of common column 'ISBN'.

# %%
books_ratings
# Out:
#                ISBN                                         Book-Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1031127  0440400988                         There's a Bat in Bunk Five
# 1031128  0525447644                            From One to One Hundred
# 1031129  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031130  0192126040                        Republic (World's Classics)
# 1031131  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 0          Mark P. O. Morford                2002
# 1        Richard Bruce Wright                2001
# 2        Richard Bruce Wright                2001
# 3        Richard Bruce Wright                2001
# 4        Richard Bruce Wright                2001
# ...                       ...                 ...
# 1031127        Paula Danziger                1988
# 1031128            Teri Sloat                1991
# 1031129      Christine Wicker                2004
# 1031130                 Plato                1996
# 1031131   Christopher  Biffle                2000
#
#                                                 Publisher  \
# 0                                 Oxford University Press
# 1                                   HarperFlamingo Canada
# 2                                   HarperFlamingo Canada
# 3                                   HarperFlamingo Canada
# 4                                   HarperFlamingo Canada
# ...                                                   ...
# 1031127                   Random House Childrens Pub (Mm)
# 1031128                                      Dutton Books
# 1031129                                HarperSanFrancisco
# 1031130                           Oxford University Press
# 1031131  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                                Image-URL-M  User-ID  \
# 0        http://images.amazon.com/images/P/0195153448.0...        2
# 1        http://images.amazon.com/images/P/0002005018.0...        8
# 2        http://images.amazon.com/images/P/0002005018.0...    11400
# 3        http://images.amazon.com/images/P/0002005018.0...    11676
# 4        http://images.amazon.com/images/P/0002005018.0...    41385
# ...                                                    ...      ...
# 1031127  http://images.amazon.com/images/P/0440400988.0...   276463
# 1031128  http://images.amazon.com/images/P/0525447644.0...   276579
# 1031129  http://images.amazon.com/images/P/006008667X.0...   276680
# 1031130  http://images.amazon.com/images/P/0192126040.0...   276680
# 1031131  http://images.amazon.com/images/P/0767409752.0...   276680
#
#          Book-Rating
# 0                  0
# 1                  5
# 2                  0
# 3                  8
# 4                  0
# ...              ...
# 1031127            7
# 1031128            4
# 1031129            0
# 1031130            0
# 1031131            0
#
# [1031132 rows x 8 columns]

# %% [markdown]
# Now we will group the books_ratings dataset on the basis of 'User-ID' to find out the number of ratings that each user has done. We will then keep only those users who have done a minimum of 200 ratings in total. This ensures that our recommendations are based on the preferences of more active and reliable users, enhancing the accuracy and trustworthiness of the personalized suggestions.

# %%
user_ratings = books_ratings.groupby('User-ID').count()['Book-Rating']

# %%
user_ratings = user_ratings.reset_index()

# %%
user_ratings = user_ratings[user_ratings['Book-Rating'] > 200]

# %%
user_ratings
# Out:
#        User-ID  Book-Rating
# 87         254          300
# 698       2276          456
# 862       2766          269
# 919       2977          227
# 1033      3363          890
# ...        ...          ...
# 90587   274308         1293
# 91112   275970         1325
# 91564   277427          490
# 91639   277639          265
# 91952   278418         3996
#
# [811 rows x 2 columns]

# %% [markdown]
# Now considering only those rows which are rated by a user who has rated atleast 200 books in total.

# %%
users = user_ratings['User-ID'].values

# %%
books_ratings = books_ratings[books_ratings['User-ID'].isin(users)]

# %% [markdown]
# Now we will do groupby on the basis of 'Book-Title' column and then considering only those books which have a total of atleast 50 ratings. This threshold ensures that the books included in the model have enough user feedback to provide meaningful collaborative filtering.

# %%
no_of_ratings = books_ratings.groupby('Book-Title').count()['Book-Rating']

# %%
no_of_ratings = no_of_ratings.reset_index()

# %%
no_of_ratings = no_of_ratings[no_of_ratings['Book-Rating'] > 50]

# %% [markdown]
# Now we will create a list of all those movies which have atleast 50 number of ratings and is rated by only those users who have done atleast 200 reviews in total and then we will filter our dataframe 'books_ratings' to include only such books.

# %%
books = no_of_ratings['Book-Title'].to_list()

# %%
books_ratings = books_ratings[books_ratings['Book-Title'].isin(books)]

# %%
books_ratings
# Out:
#                ISBN                       Book-Title      Book-Author  \
# 31       0399135782           The Kitchen God's Wife          Amy Tan
# 33       0399135782           The Kitchen God's Wife          Amy Tan
# 34       0399135782           The Kitchen God's Wife          Amy Tan
# 38       0399135782           The Kitchen God's Wife          Amy Tan
# 39       0399135782           The Kitchen God's Wife          Amy Tan
# ...             ...                              ...              ...
# 1028410  1878702831                           Echoes      Nancy Morse
# 1028596  0394429869  I Know Why the Caged Bird Sings     Maya Angelou
# 1028598  0449001164                      The Promise      CHAIM POTOK
# 1028811  0743527631         The Pillars of the Earth      Ken Follett
# 1028813  0745168086              The Handmaid's Tale  Margaret Atwood
#
#         Year-Of-Publication                      Publisher  \
# 31                     1991               Putnam Pub Group
# 33                     1991               Putnam Pub Group
# 34                     1991               Putnam Pub Group
# 38                     1991               Putnam Pub Group
# 39                     1991               Putnam Pub Group
# ...                     ...                            ...
# 1028410                1992  Meteor Publishing Corporation
# 1028596                1996                   Random House
# 1028598                1997               Ballantine Books
# 1028811                2002                         Encore
# 1028813                1999            Chivers Audio Books
#
#                                                Image-URL-M  User-ID  \
# 31       http://images.amazon.com/images/P/0399135782.0...    11676
# 33       http://images.amazon.com/images/P/0399135782.0...    36836
# 34       http://images.amazon.com/images/P/0399135782.0...    46398
# 38       http://images.amazon.com/images/P/0399135782.0...   113270
# 39       http://images.amazon.com/images/P/0399135782.0...   113519
# ...                                                    ...      ...
# 1028410  http://images.amazon.com/images/P/1878702831.0...   238781
# 1028596  http://images.amazon.com/images/P/0394429869.0...   239594
# 1028598  http://images.amazon.com/images/P/0449001164.0...   239594
# 1028811  http://images.amazon.com/images/P/0743527631.0...   240144
# 1028813  http://images.amazon.com/images/P/0745168086.0...   240144
#
#          Book-Rating
# 31                 9
# 33                 0
# 34                 9
# 38                 0
# 39                 0
# ...              ...
# 1028410            0
# 1028596            8
# 1028598            7
# 1028811            0
# 1028813            0
#
# [57236 rows x 8 columns]

# %% [markdown]
# Now we will create a pivot table that creates a matrix where each cell represents the rating a user has given to a particular book.

# %%
pt = books_ratings.pivot_table(index = 'Book-Title', columns = 'User-ID', values = 'Book-Rating')

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     0.0     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   NaN  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     NaN
# 2nd Chance                                             0.0  ...     NaN
# 4 Blondes                                              NaN  ...     NaN
# A Bend in the Road                                     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   0.0     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   NaN     NaN     0.0
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     0.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     0.0
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    8.0     NaN     NaN
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [679 rows x 810 columns]

# %% [markdown]
# Filling NaN values by 0 in the pivot table.

# %%
pt = pt.fillna(0)

# %% [markdown]
# Now we will calculate cosine similarity which is a measure that calculates the cosine of the angle between two vectors, often used to determine similarity between items in a recommendation system. In our case, it computes the cosine similarity between the rows of the pivot table pt, where each row corresponds to a book and contains ratings given by different users.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# similarity_scores is a matrix where each element represents the similarity score between two books. This similarity is based on cosine_similarity. Higher scores indicate greater similarity.
# So, in our case similarity_scores is a matrix which gives similarity of one book with other 679 books and with itself(which is 1). Therefore the shape of similiarity_scores matrix is (679,679).

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (679, 679)

# %% [markdown]
# Creating a function that recommends 5 books, its author and its cover page image url, based on collaborative filtering approach.

# %%
def recommend(book_name):
    books_list = list(pt.index)
    ind = books_list.index(book_name)
    similarity_scores_list = list(similarity_scores[ind])
    d = {}
    l = []
    for i in similarity_scores_list:
        d[i] = similarity_scores_list.index(i)
    d = dict(sorted(d.items(),reverse=True))
    for i in d.values():
        l.append(i)
    l = l[1:6]
    for i in l:
        print('Book name:', pt.index[i])
        print('Author name:', books_ratings[books_ratings['Book-Title'] == pt.index[i]]['Book-Author'].unique()[0])
        print('Book image url:', books_ratings[books_ratings['Book-Title'] == pt.index[i]]['Image-URL-M'].unique()[0])
        print('\n')

# %%
recommend('Harry Potter and the Goblet of Fire (Book 4)')
# Out:
# Book name: Harry Potter and the Prisoner of Azkaban (Book 3)
# Author name: J. K. Rowling
# Book image url: http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg
#
#
# Book name: Harry Potter and the Chamber of Secrets (Book 2)
# Author name: J. K. Rowling
# Book image url: http://images.amazon.com/images/P/0439064872.01.MZZZZZZZ.jpg
#
#
# Book name: Harry Potter and the Order of the Phoenix (Book 5)
# Author name: J. K. Rowling
# Book image url: http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg
#
#
# Book name: Harry Potter and the Sorcerer's Stone (Book 1)
# Author name: J. K. Rowling
# Book image url: http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg
#
#
# Book name: Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# Author name: J. K. Rowling
# Book image url: http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg
